# %% [markdown]
# # 📝 문제 제목 (BOJ 1157)
#
# ## 📌 문제 링크
# https://www.acmicpc.net/problem/1157
#
# ---
#
# ## 🔍 문제 요약
# - 문자열에서 가장 많이 등장하는 알파벳 출력
# - 대소문자 구분 X
# - 동률이면 '?'
#
# ---
#
# ## 🎯 요구사항 정리
# - 문자열 길이 ≤ 1,000,000
# - 대문자로 통일 후 등장 빈도 계산
#
# ---
#
# ## 💡 접근 방식
# 1. 문자열을 Uppercase로 변환
# 2. Counter로 개수 세기
# 3. 최댓값이 여러 개면 '?'
# 4. 아니면 해당 문자 출력
#
# ---
#
# ## 🧠 의사코드(Pseudocode)
# 문자열 = input()
# 대문자로 변환
# 카운터로 개수세기 (결과는 해시맵으로 저장됨)
# 해시맵에 저장된 value중 가장 많은것은 어떻게 찾을까?
# 만약에 중복이 있다면?
#
# ## 예제입력
# Mississipi
# zZa

# %%
s = input().upper()

# 1. 문자 개수 세기
count = {}
for ch in s:
    if ch not in count:
        count[ch] = 1
    else:
        count[ch] += 1

# 2. 최댓값 찾기
max_count = 0
for ch in count:
    if count[ch] > max_count:
        max_count = count[ch]

# 3. 최댓값 문자들 모으기
max_chars = []
for ch in count:
    if count[ch] == max_count:
        max_chars.append(ch)

# 4. 출력
if len(max_chars) > 1:
    print('?')
else:
    print(max_chars[0])
# Out:
#  Mississipi
# ?
